# %% [markdown]
# Machince learning - The ability of computer to learns on itsown without explict programming
#
# ML Algorithm:
# 1. Supervised Learning - widely used in real world application
# 2. Unsupervised Learning
# 3. Reinforcement Learning
#
#
# Supervised Learning:
#
# ![image.png](data:image/png;base64,...)
#
# Regression
#
# ![image.png](data:image/png;base64,...)
#
# Classification
#
# ![image.png](data:image/png;base64,...)
#
# Two or More inputs -> Boundary is used
# ![image.png](data:image/png;base64,...)
#
# Summary:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# UnSupervised Learning Algorithm:
#
# Find the something interesting in unlabeled data.
#
# Supervised vs unsupervised
#
# ![image.png](data:image/png;base64,...)
#
# Clustering -> Google news
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# Anomaly Detections and Dimensionality reduction
#
# ![image.png](data:image/png;base64,...)
